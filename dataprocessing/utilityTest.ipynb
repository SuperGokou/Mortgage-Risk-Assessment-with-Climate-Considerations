# %%
import utility as util
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import pandas as pd
import seaborn as sns
import math
from google.cloud import vision

# %%
df = pd.read_csv('data\pend-gdis-1960-2018-disasterlocations.csv')
display(df.head())
# Out:
#     id  country iso3   gwno  year  geo_id  geolocation  level     adm1  \
# 0  109  Albania  ALB  339.0  2009     346  Ana E Malit      3  Shkoder
# 1  109  Albania  ALB  339.0  2009     351       Bushat      3  Shkoder
# 2  175   Angola  AGO  540.0  2001     760       Onjiva      3   Cunene
# 3  187   Angola  AGO  540.0  2009     710        Evale      3   Cunene
# 4  187   Angola  AGO  540.0  2009     749         Mupa      3   Cunene
#
#        adm2         adm3     location  historical hist_country disastertype  \
# 0  Shkodres  Ana E Malit  Ana E Malit           0          NaN        flood
# 1  Shkodres       Bushat       Bushat           0          NaN        flood
# 2  Cuanhama       Onjiva       Onjiva           0          NaN        flood
# 3  Cuanhama        Evale        Evale           0          NaN        flood
# 4   Cuvelai         Mupa         Mupa           0          NaN        flood
#
#   disasterno   latitude  longitude
# 0  2009-0631  42.020948  19.418317
# ...

# %%
# Linear Regression
X = df['latitude']
Y = df['longitude']
LL_model = util.LinearRegression(X, Y)
LL_model.summary_table()
# Out:
# Linear Regression Function: y = 35.9796947552844 + (-0.1417725087527862) * x
# Mean Square Error (MSE): 6419.4998
# R^2 Score: 0.0014
# Intercept (b0): 35.9797
# Slope (b1): -0.1418
# The plot displays a linear regression model in the color electric blue. The points on the plot form a circle pattern, possibly indicating a consistent relationship between the variables. The font used in the plot may also be distinctive. Additionally, there is a rectangular logo or symbol present, possibly related to a specific brand or company. Overall, the color scheme includes electric blue and peach tones, giving the plot a visually appealing and cohesive look. The description suggests a focus on aesthetics and branding in the presentation of the linear regression model.

# %%
LG_model = util.LogisticRegression(X, Y)
LG_model.summary_table()
# Out:
# Logistic Regression Function: p(y = 1 | x) = σ(0.0000 + 0.0000 * x)
# Learning Rate: 0.01
# Epochs: 1000
# Intercept: 0.0000
# Coefficient of X: 0.0000
# ...
